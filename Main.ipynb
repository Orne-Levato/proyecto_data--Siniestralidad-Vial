# %% [markdown]
# <a href="https://colab.research.google.com/github/Orne-Levato/proyecto_data--Siniestralidad-Vial/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
